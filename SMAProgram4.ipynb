# %% [markdown]
# <a href="https://colab.research.google.com/github/PavankumarUppar/SMA/blob/main/SMAProgram4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#a
import requests
from bs4 import BeautifulSoup

def extract_hyperlinks(url):
   response = requests.get(url)
   soup = BeautifulSoup(response.text, 'html.parser')
  
   hyperlinks = []
  
   for link in soup.find_all('a'):
       href = link.get('href')
       if href:
           hyperlinks.append(href)
  
   return hyperlinks

# Example usage
webpage_url = "https://en.wikipedia.org/wiki/Schr%C3%B6dinger%27s_cat"
hyperlinks = extract_hyperlinks(webpage_url)

for link in hyperlinks:
   print(link)
# Out:
# #bodyContent
# /wiki/Main_Page
# /wiki/Wikipedia:Contents
# /wiki/Portal:Current_events
# /wiki/Special:Random
# /wiki/Wikipedia:About
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en
# /wiki/Help:Contents
# /wiki/Help:Introduction
# /wiki/Wikipedia:Community_portal
# /wiki/Special:RecentChanges
# /wiki/Wikipedia:File_upload_wizard
# /wiki/Main_Page
# /wiki/Special:Search
# /w/index.php?title=Special:CreateAccount&returnto=Schr%C3%B6dinger%27s+cat
# /w/index.php?title=Special:UserLogin&returnto=Schr%C3%B6dinger%27s+cat
# /w/index.php?title=Special:CreateAccount&returnto=Schr%C3%B6dinger%27s+cat
# /w/index.php?title=Special:UserLogin&returnto=Schr%C3%B6dinger%27s+cat
# /wiki/Help:Introduction
# /wiki/Special:MyContributions
# /wiki/Special:MyTalk
# #
# #Origin_and_motivation
# #Thought_experiment
# #Interpretations
# ...

# %%
#b
import requests
from bs4 import BeautifulSoup

def retrieve_titles_from_wikipedia(url):
   response = requests.get(url)
   soup = BeautifulSoup(response.text, 'html.parser')
  
   titles = []
  
   for title in soup.find_all('span', {'class': 'mw-headline'}):
       titles.append(title.text)
  
   return titles

# Example usage
wikipedia_url = "https://en.wikipedia.org/wiki/Python_(programming_language)"
titles = retrieve_titles_from_wikipedia(wikipedia_url)

for title in titles:
   print(title)
# Out:
# History
# Design philosophy and features
# Syntax and semantics
# Indentation
# Statements and control flow
# Expressions
# Methods
# Typing
# Arithmetic operations
# Programming examples
# Libraries
# Development environments
# Implementations
# Reference implementation
# Other implementations
# Unsupported implementations
# Cross-compilers to other languages
# Performance
# Development
# API documentation generators
# Naming
# Popularity
# Uses
# Languages influenced by Python
# See also
# References
# Sources
# Further reading
# External links
